# %% [markdown]
# <div style="text-align:left;font-size:2em"><span style="font-weight:bolder;font-size:1.25em">SP2273 | Learning Portfolio</span><br><br><span style="font-weight:bold;color:darkred">Plotting (Good)</span></div>

# %% [markdown]
# ## 1 Comparing the two ‘dialects’

# %% [markdown]
# ### 1.1 Some nomenclature

# %%
from matplotlib import pyplot as plt

# %%
#figure = full canvas you can use to draw stuff on
#axis= the individual mathematical axes we use for plotting.

# %% [markdown]
# ### 1.2 We need some data.

# %%
x = np.linspace(-np.pi, np.pi, num=100)
cos_x = np.cos(x)
sin_x = np.sin(x)

# %% [markdown]
# ### 1.3 Here comes the comparison

# %%
plt.plot(x, cos_x, label='cos x')
plt.plot(x, sin_x, label='sin x')
plt.legend()
plt.show()

# %%
fig, ax = plt.subplots(nrows=1, ncols=1)
ax.plot(x, cos_x, label='cos x')
ax.plot(x, sin_x, label='sin x')
ax.legend()
plt.show()

# %% [markdown]
# ## 2 Using the OO Interface

# %% [markdown]
# ### 2.1 Getting ax

# %%
fig, ax = plt.subplots(ncols=1, nrows=2)

# %% [markdown]
# ### 2.2 What is ax

# %%
type(ax)
# Out:
# numpy.ndarray

# %%
type(ax)
# Out:
# numpy.ndarray

# %% [markdown]
# ### 2.3 Plots in a column

# %%
# Your code here

# %% [markdown]
# ### 2.4 Legends

# %%
# Your code here

# %% [markdown]
# ### 2.5 Tweaks

# %%
# Your code here

# %% [markdown]
# ## 3 More rows and columns

# %% [markdown]
# ### 3.1 Using ax

# %%
# Your code here

# %% [markdown]
# ### 3.2 Sharing axes

# %%
# Your code here

# %% [markdown]
# ### 3.3 Accessing all axes

# %%
# Your code here

# %% [markdown]
# ## 4 Other useful plots

# %% [markdown]
# ### 4.1 Histograms

# %%
# Your code here

# %% [markdown]
# ### 4.2 Scatter plots

# %%
# Your code here

# %% [markdown]
# ### 4.3 Bar charts

# %%
# Your code here

# %% [markdown]
# ### 4.4 Pie charts

# %%
# Your code here

# %% [markdown]
# ## Exercise 1 :  Plotting data from files

# %%
# Your solution here
